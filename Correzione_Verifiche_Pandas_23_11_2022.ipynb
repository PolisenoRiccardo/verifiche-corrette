# %% [markdown]
# <a href="https://colab.research.google.com/github/PolisenoRiccardo/verifiche/blob/main/Correzione_Verifiche_Pandas_23_11_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Verifica 1

# %% [markdown]
# Analizzare attentamente il file per capire bene come sono strutturati i dati e che cosa contengono. Creare poi un nuovo notebook, chiamandolo con il proprio cognome, in cui scrivere le istruzioni necessarie per:

# %% [markdown]
# 1. caricare i dati del file in un dataframe Pandas

# %%
import pandas as pd
movies = pd.read_csv('https://raw.githubusercontent.com/wtitze/3E/main/2010.csv', delimiter=';')
movies
# Out:
#                                      Title    Year  \
# 0                               127 Hours   2010.0
# 1                             3 Backyards   2010.0
# 2                                       3   2010.0
# 3               8: The Mormon Proposition   2010.0
# 4     A Turtle's Tale: Sammy's Adventures   2010.0
# ...                                    ...     ...
# 1599              War & Peace                  NaN
# 1600                    Wings                  NaN
# 1601               Wolf Creek                  NaN
# 1602        Wuthering Heights                  NaN
# 1603  Yu-Gi-Oh! Duel Monsters                  NaN
#
#                                          Genres  Language    Country  \
# 0            Adventure|Biography|Drama|Thriller   English        USA
# 1                                         Drama   English        USA
# 2                          Comedy|Drama|Romance    German    Germany
# 3                                   Documentary   English        USA
# ...

# %% [markdown]
# 2. visualizzare le colonne del titolo e del genere dei primi 10 film

# %%
movies.iloc[:10][['Title', 'Genres']]
# Out:
#                                   Title  \
# 0                            127 Hours
# 1                          3 Backyards
# 2                                    3
# 3            8: The Mormon Proposition
# 4  A Turtle's Tale: Sammy's Adventures
# 5                  Alice in Wonderland
# 6                  Alice in Wonderland
# 7                      All Good Things
# 8                      Alpha and Omega
# 9                                Amigo
#
#                                       Genres
# 0         Adventure|Biography|Drama|Thriller
# 1                                      Drama
# 2                       Comedy|Drama|Romance
# 3                                Documentary
# 4                 Adventure|Animation|Family
# 5                   Adventure|Family|Fantasy
# 6                   Adventure|Family|Fantasy
# 7       Crime|Drama|Mystery|Romance|Thriller
# 8  Adventure|Animation|Comedy|Family|Romance
# 9                                  Drama|War

# %% [markdown]
# 3. visualizzare le colonne del titolo e del genere dei primi 10 film in un modo diverso dal precedente

# %%
movies.head(10)[['Title', 'Genres']]
# Out:
#                                   Title  \
# 0                            127 Hours
# 1                          3 Backyards
# 2                                    3
# 3            8: The Mormon Proposition
# 4  A Turtle's Tale: Sammy's Adventures
# 5                  Alice in Wonderland
# 6                  Alice in Wonderland
# 7                      All Good Things
# 8                      Alpha and Omega
# 9                                Amigo
#
#                                       Genres
# 0         Adventure|Biography|Drama|Thriller
# 1                                      Drama
# 2                       Comedy|Drama|Romance
# 3                                Documentary
# 4                 Adventure|Animation|Family
# 5                   Adventure|Family|Fantasy
# 6                   Adventure|Family|Fantasy
# 7       Crime|Drama|Mystery|Romance|Thriller
# 8  Adventure|Animation|Comedy|Family|Romance
# 9                                  Drama|War

# %%
movies[['Title', 'Genres']][:10]
# Out:
#                                   Title  \
# 0                            127 Hours
# 1                          3 Backyards
# 2                                    3
# 3            8: The Mormon Proposition
# 4  A Turtle's Tale: Sammy's Adventures
# 5                  Alice in Wonderland
# 6                  Alice in Wonderland
# 7                      All Good Things
# 8                      Alpha and Omega
# 9                                Amigo
#
#                                       Genres
# 0         Adventure|Biography|Drama|Thriller
# 1                                      Drama
# 2                       Comedy|Drama|Romance
# 3                                Documentary
# 4                 Adventure|Animation|Family
# 5                   Adventure|Family|Fantasy
# 6                   Adventure|Family|Fantasy
# 7       Crime|Drama|Mystery|Romance|Thriller
# 8  Adventure|Animation|Comedy|Family|Romance
# 9                                  Drama|War

# %% [markdown]
# 4. visualizzare i film in inglese realizzati in Francia

# %%
movies[(movies.Language == 'English') & (movies.Country == 'France')]
# Out:
#                                       Title    Year  \
# 4      A Turtle's Tale: Sammy's Adventures   2010.0
# 59                    From Paris with Love   2010.0
# 64                              Green Zone   2010.0
# 139                                 Rubber   2010.0
# 179                       The Ghost Writer   2010.0
# 185                      The Last Exorcism   2010.0
# 262                                Carnage   2011.0
# 266                             Colombiana   2011.0
# 374                           Silent House   2011.0
# 391                             The Artist   2011.0
# 432              Tinker Tailor Soldier Spy   2011.0
# 543                                Lockout   2012.0
# 550                                 Maniac   2012.0
# 558                            On the Road   2012.0
# 588             Silent Hill: Revelation 3D   2012.0
# 604                                Taken 2   2012.0
# 715                             Blood Ties   2013.0
# ...

# %% [markdown]
# 5. visualizzare i film di guerra drammatici

# %%
movies[(movies.Genres.str.contains('Drama')) & (movies.Genres.str.contains('War'))]
# Out:
#                                                 Title    Year  \
# 9                                              Amigo   2010.0
# 16                                   Beneath Hill 60   2010.0
# 28                                         Centurion   2010.0
# 37                                         Dear John   2010.0
# 64                                        Green Zone   2010.0
# 78                                         Incendies   2010.0
# 142                                      Sarah's Key   2010.0
# 230                                             1911   2011.0
# 232                                    5 Days of War   2011.0
# 268                                       Coriolanus   2011.0
# 284                                       Fort McCoy   2011.0
# 308                   In the Land of Blood and Honey   2011.0
# 402                               The Flowers of War   2011.0
# 430                                 There Be Dragons   2011.0
# ...

# %% [markdown]
# 6. visualizzare i film fantasy e i thriller

# %%
movies[(movies.Genres.str.contains('Fantasy')) | (movies.Genres.str.contains('Thriller'))]
# Out:
#                                      Title    Year  \
# 0                               127 Hours   2010.0
# 5                     Alice in Wonderland   2010.0
# 6                     Alice in Wonderland   2010.0
# 7                         All Good Things   2010.0
# 17               Beyond the Black Rainbow   2010.0
# ...                                    ...     ...
# 1591               The Secret                  NaN
# 1594                  Trapped                  NaN
# 1595                  Twisted                  NaN
# 1601               Wolf Creek                  NaN
# 1603  Yu-Gi-Oh! Duel Monsters                  NaN
#
#                                          Genres   Language    Country  \
# 0            Adventure|Biography|Drama|Thriller    English        USA
# 5                      Adventure|Family|Fantasy    English        USA
# 6                      Adventure|Family|Fantasy    English        USA
# ...

# %% [markdown]
# 7. visualizzare il budget complessivo dei film realizzati in Spagna

# %%
movies[movies['Country'] == 'Spain']['Budget'].sum()
# Out:
# 150000000.0

# %% [markdown]
# 8. visualizzare il numero di film di guerra realizzati in Spagna

# %%
len(movies[(movies['Country'] == 'Spain') & (movies.Genres.str.contains('War'))])
# Out:
# 1

# %%
movies[(movies['Country'] == 'Spain') & (movies.Genres.str.contains('War'))]['Title'].count()
# Out:
# 1

# %% [markdown]
# 9. visualizzare i titoli dei film di cui non si conosce il budget

# %%
movies[movies.Budget.isnull()]['Title']
# Out:
# 2                                         3
# 4       A Turtle's Tale: Sammy's Adventures
# 7                           All Good Things
# 11                           Animals United
# 13                         Barney's Version
#                         ...
# 1599                War & Peace
# 1600                      Wings
# 1601                 Wolf Creek
# 1602          Wuthering Heights
# 1603    Yu-Gi-Oh! Duel Monsters
# Name: Title, Length: 254, dtype: object

# %% [markdown]
# 10. visualizzare i titoli dei film e il relativo regista. Ordinare a partire dal film che ha il budget più alto

# %%
movies.sort_values(by='Budget', ascending=False)[['Title', 'Director']]
# Out:
#                                              Title           Director
# 90                                          Kites         Anurag Basu
# 534                                   John Carter      Andrew Stanton
# 163                                       Tangled        Nathan Greno
# 351   Pirates of the Caribbean: On Stranger Tides        Rob Marshall
# 618                         The Dark Knight Rises   Christopher Nolan
# ...                                            ...                ...
# 1599                      War & Peace                             NaN
# 1600                            Wings                             NaN
# 1601                       Wolf Creek                             NaN
# 1602                Wuthering Heights                             NaN
# 1603          Yu-Gi-Oh! Duel Monsters                             NaN
#
# [1604 rows x 2 columns]

# %% [markdown]
# 11. visualizzare i titoli dei film che hanno incassato più di quanto è stato speso per realizzarli

# %%
movies[movies['Budget'] < movies['Gross Earnings']]['Title']
# Out:
# 0                      127 Hours
# 5            Alice in Wonderland
# 6            Alice in Wonderland
# 8                Alpha and Omega
# 15                     Beginners
#                   ...
# 1477             The Jungle Book
# 1483           The Perfect Match
# 1484    The Purge: Election Year
# 1485     The Secret Life of Pets
# 1486                The Shallows
# Name: Title, Length: 548, dtype: object

# %% [markdown]
# 12. visualizzare i film in cui ha recitato Johnny Depp

# %%
movies[(movies['Actor 1'] == 'Johnny Depp') | (movies['Actor 2'] == 'Johnny Depp') | (movies['Actor 3'] == 'Johnny Depp')]
# Out:
#                                              Title    Year  \
# 5                             Alice in Wonderland   2010.0
# 6                             Alice in Wonderland   2010.0
# 201                                   The Tourist   2010.0
# 202                                   The Tourist   2010.0
# 351   Pirates of the Caribbean: On Stranger Tides   2011.0
# 357                                         Rango   2011.0
# 493                                  Dark Shadows   2012.0
# 874                               The Lone Ranger   2013.0
# 1020                               Into the Woods   2014.0
# 1145                                Transcendence   2014.0
# 1148                                         Tusk   2014.0
# 1187                                   Black Mass   2015.0
# 1278                                    Mortdecai   2015.0
# 1395              Alice Through the Looking Glass   2016.0
# 1495                                  Yoga Hosers   2016.0
#
# ...

# %% [markdown]
# 13. visualizzare il regista che ha ricevuto più like su Facebook per un suo film

# %%
movies[movies['Facebook likes - Movie'] == max(movies['Facebook likes - Movie'])]['Director']
# Out:
# 1018    Christopher Nolan
# Name: Director, dtype: object

# %% [markdown]
# 14. visualizzare i film che hanno avuto un numero di like superiore alla media dei like assegnati ai film

# %%
movies[movies['Facebook likes - Movie'] > movies['Facebook likes - Movie'].mean()]
# Out:
#                                           Title    Year  \
# 0                                    127 Hours   2010.0
# 5                          Alice in Wonderland   2010.0
# 6                          Alice in Wonderland   2010.0
# 18                                    Biutiful   2010.0
# 19                                  Black Swan   2010.0
# ...                                         ...     ...
# 1530                      Hannibal                  NaN
# 1543                        Luther                  NaN
# 1549                     Outlander                  NaN
# 1568  Spartacus: War of the Damned                  NaN
# 1580                 The Following                  NaN
#
#                                         Genres Language Country  \
# 0           Adventure|Biography|Drama|Thriller  English     USA
# 5                     Adventure|Family|Fantasy  English     USA
# 6                     Adventure|Family|Fantasy  English     USA
# ...

# %% [markdown]
# 15. verificare se durano di più, in media, i film americani o i film tedeschi

# %%
if movies[movies['Country']=='USA']['Duration'].mean() > movies[movies['Country']=='Germany']['Duration'].mean():
  print('I film Americani durano mediamente di più rispetto a quelli Tedeschi')
else:
  print('I film Tedeschi durano mediamente di più rispetto a quelli Americani')
# Out:
# I film Tedeschi durano mediamente di più rispetto a quelli Americani

# %% [markdown]
# 16. aggiungere una colonna al dataframe contenente la somma dei like degli attori. Chiamare la colonna 'attori'

# %%
movies['Attori'] = movies['Facebook Likes - Actor 1'] + movies['Facebook Likes - Actor 2'] + movies['Facebook Likes - Actor 3']

# %% [markdown]
# 17. rimuovere la colonna appena creata

# %%
del movies['Attori']

# %% [markdown]
# 18. eliminare dal dataframe i film italiani

# %%
movies = movies.drop(movies.index[[movies.index.values[movies['Country'] == 'Italy']]])
movies
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py:4616: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result = getitem(key)
#                                      Title    Year  \
# 0                               127 Hours   2010.0
# 1                             3 Backyards   2010.0
# 2                                       3   2010.0
# 3               8: The Mormon Proposition   2010.0
# 4     A Turtle's Tale: Sammy's Adventures   2010.0
# ...                                    ...     ...
# 1599              War & Peace                  NaN
# 1600                    Wings                  NaN
# 1601               Wolf Creek                  NaN
# 1602        Wuthering Heights                  NaN
# ...

# %% [markdown]
# #Verifica 2

# %% [markdown]
# Analizzare attentamente il file per capire bene come sono strutturati i dati e che cosa contengono. Creare poi un nuovo notebook chiamandolo con il proprio cognome in cui scrivere le istruzioni necessarie per:

# %% [markdown]
# 1. caricare i dati del file in un dataframe Pandas

# %%
medals =  pd.read_excel('https://raw.githubusercontent.com/wtitze/3E/main/Medals.xlsx')
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %% [markdown]
# 2. visualizzare il totale delle medaglie delle prime 10 nazioni

# %%
medals.head(10)['Total']
# Out:
# 0    113
# 1     88
# 2     58
# 3     65
# 4     71
# 5     46
# 6     36
# 7     33
# 8     37
# 9     40
# Name: Total, dtype: int64

# %% [markdown]
# 3. visualizzare la nazione (o le nazioni) che ha vinto, in totale, meno medaglie

# %%
medals[medals.Total == medals['Total'].min()]
# Out:
#     Rank              Team/NOC  Gold  Silver  Bronze  Total  Rank by Total
# 62    63               Bermuda     1       0       0      1             77
# 63    63               Morocco     1       0       0      1             77
# 64    63           Puerto Rico     1       0       0      1             77
# 76    77               Bahrain     0       1       0      1             77
# 77    77          Saudi Arabia     0       1       0      1             77
# 78    77             Lithuania     0       1       0      1             77
# 79    77       North Macedonia     0       1       0      1             77
# 80    77               Namibia     0       1       0      1             77
# 81    77          Turkmenistan     0       1       0      1             77
# 85    86              Botswana     0       0       1      1             77
# 86    86          Burkina Faso     0       0       1      1             77
# ...

# %% [markdown]
# 4. visualizzare le nazioni che hanno vinto più medaglie di bronzo rispetto alle medaglie d'argento

# %%
medals[medals.Bronze > medals.Silver]
# Out:
#     Rank              Team/NOC  Gold  Silver  Bronze  Total  Rank by Total
# 2      3                 Japan    27      14      17     58              5
# 3      4         Great Britain    22      21      22     65              4
# 5      6             Australia    17       7      22     46              6
# 6      7           Netherlands    10      12      14     36              9
# 8      9               Germany    10      11      16     37              8
# 9     10                 Italy    10      10      20     40              7
# 10    11                Canada     7       6      11     24             11
# 11    12                Brazil     7       6       8     21             12
# 12    13           New Zealand     7       6       7     20             13
# 13    14                  Cuba     7       3       5     15             18
# 15    16     Republic of Korea     6       4      10     20             13
# ...

# %% [markdown]
# 5. visualizzare il numero di nazioni che non hanno vinto medaglie d'oro

# %%
medals[medals.Gold == 0]['Rank'].count()
# Out:
# 28

# %% [markdown]
# 6. visualizzare il numero totale di medaglie d'oro e d'argento

# %%
medals[['Gold', 'Silver']].sum()
# Out:
# Gold      340
# Silver    338
# dtype: int64

# %% [markdown]
# 7. visualizzare la nazione che ha vinto più medaglie di bronzo

# %%
medals[medals.Bronze == medals['Bronze'].max()]
# Out:
#    Rank                  Team/NOC  Gold  Silver  Bronze  Total  Rank by Total
# 0     1  United States of America    39      41      33    113              1

# %% [markdown]
# 8. visualizzare le nazioni che non hanno vinto medaglie d'argento

# %%
medals[medals.Silver == 0]
# Out:
#     Rank              Team/NOC  Gold  Silver  Bronze  Total  Rank by Total
# 31    32            Uzbekistan     3       0       2      5             42
# 38    39               Ireland     2       0       2      4             47
# 39    39                Israel     2       0       2      4             47
# 40    41                 Qatar     2       0       1      3             60
# 41    42               Bahamas     2       0       0      2             66
# 42    42                Kosovo     2       0       0      2             66
# 58    59               Estonia     1       0       1      2             66
# 59    59                  Fiji     1       0       1      2             66
# 60    59                Latvia     1       0       1      2             66
# 61    59              Thailand     1       0       1      2             66
# 62    63               Bermuda     1       0       0      1             77
# ...

# %% [markdown]
# 9. visualizzare le nazioni che hanno vinto un numero di medaglie d'argento superiore alla media

# %%
medals[medals.Silver > medals.Silver.mean()]
# Out:
#     Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0      1    United States of America    39      41      33    113
# 1      2  People's Republic of China    38      32      18     88
# 2      3                       Japan    27      14      17     58
# 3      4               Great Britain    22      21      22     65
# 4      5                         ROC    20      28      23     71
# 5      6                   Australia    17       7      22     46
# 6      7                 Netherlands    10      12      14     36
# 7      8                      France    10      12      11     33
# 8      9                     Germany    10      11      16     37
# 9     10                       Italy    10      10      20     40
# 10    11                      Canada     7       6      11     24
# 11    12                      Brazil     7       6       8     21
# 12    13                 New Zealand     7       6       7     20
# ...

# %% [markdown]
# Analizzare attentamente il file per capire bene come sono strutturati i dati e che cosa contengono. Scrivere poi le istruzioni necessarie per:

# %% [markdown]
# 10. caricare i dati del file in un dataframe Pandas

# %%
atleti = pd.read_excel('https://raw.githubusercontent.com/wtitze/3E/main/Athletes.xlsx')

# %% [markdown]
# 11. visualizzare i nomi degli atleti italiani

# %%
atleti[atleti.NOC == 'Italy']['Name']
# Out:
# 2               ABAGNALE Giovanni
# 27               ABDELWAHED Ahmed
# 72              ACERENZA Domenico
# 73                 ACETI Vladimir
# 131      AGIURGIUCULESE Alexandra
#                    ...
# 10958              ZAZA Francesco
# 10961             ZAZZERI Lorenzo
# 10976              ZENNARO Silvia
# 11061                ZOGHLAMI Ala
# 11062              ZOGHLAMI Osama
# Name: Name, Length: 356, dtype: object

# %% [markdown]
# 12. controllare se gli atleti italiani sono di più o di meno degli atleti francesi

# %%
if len(atleti[atleti.NOC == 'Italy']) > len(atleti[atleti.NOC == 'France']):
  print('Gli atleti Italiani sono maggiori rispetto agli atleti Francesi.')
elif len(atleti[atleti.NOC == 'Italy']) < len(atleti[atleti.NOC == 'France']):
  print('Gli atleti Francesi sono maggiori rispetto agli atleti Italiani.')
# Out:
# Gli atleti Francesi sono maggiori rispetto agli atleti Italiani.

# %% [markdown]
# 13. visualizzare tutti gli atleti che si chiamano Giovanni

# %%
atleti[atleti.Name.str.contains('Giovanni')]
# Out:
#                       Name     NOC     Discipline
# 2        ABAGNALE Giovanni   Italy         Rowing
# 2173   de GENNARO Giovanni   Italy   Canoe Slalom
# 2778       FALOCI Giovanni   Italy      Athletics
# 9739        TOCCI Giovanni   Italy         Diving
# 10235      VIANNA Giovanni  Brazil  Skateboarding

# %% [markdown]
# 14. visualizzare gli atleti che si chiamano Alberto ma che non sono italiani

# %%
atleti[(atleti.Name.str.contains('Alberto')) & (atleti.NOC != 'Italy')]
# Out:
#                                   Name                 NOC          Discipline
# 3                       ABALDE Alberto               Spain          Basketball
# 502              AREVALO ALCON Alberto               Spain              Diving
# 594      AULAR SANABRIA Orluis Alberto           Venezuela        Cycling Road
# 2836                 FERNANDEZ Alberto               Spain            Shooting
# 3091            GAITERO MARTIN Alberto               Spain                Judo
# 3141         GARCIA BRITO Luis Alberto  Dominican Republic       Weightlifting
# 3305               GINES LOPEZ Alberto               Spain      Sport Climbing
# 6056                  MARTINEZ Alberto               Spain   Marathon Swimming
# 6372                    MESTRE Alberto           Venezuela            Swimming
# 6400                    MICHAN Alberto              Israel          Equestrian
# 6472                      MINO Alberto             Ecuador        Table Tennis
# ...

# %% [markdown]
# 15. visualizzare il numero di atleti della squadra di basket spagnola

# %%
len(atleti[(atleti.NOC == 'Spain') & (atleti.Discipline == 'Basketball')])
# Out:
# 24

# %% [markdown]
# 16. visualizzare i dati del dataframe ordinati in ordine alfabetico sulla disciplina

# %%
atleti.sort_values('Discipline', ascending=True)
# Out:
#                               Name          NOC      Discipline
# 1569                  CAVARS Agnis       Latvia  3x3 Basketball
# 6168              MAWULI Stephanie        Japan  3x3 Basketball
# 9088                 SLAGTER Arvin  Netherlands  3x3 Basketball
# 3039                 FROLKINA Olga          ROC  3x3 Basketball
# 3038             FROLKINA Evgeniia          ROC  3x3 Basketball
# ...                            ...          ...             ...
# 4537  KADZIMAHAMEDAU Mahamedkhabib      Belarus       Wrestling
# 6410           MICIC Stevan Andria       Serbia       Wrestling
# 799            BAT OCHIR Bolortuya     Mongolia       Wrestling
# 9262                STADNIK Mariya   Azerbaijan       Wrestling
# 9197       SORONZONBOLD Battsetseg     Mongolia       Wrestling
#
# [11085 rows x 3 columns]

# %% [markdown]
# 17. visualizzare gli atleti scandinavi

# %%
atleti[(atleti.NOC == 'Sweden') | (atleti.NOC == 'Norway') | (atleti.NOC == 'Finland')]
# Out:
#                       Name     NOC           Discipline
# 0          AALERUD Katrine  Norway         Cycling Road
# 50     ABELVIK ROED Magnus  Norway             Handball
# 105         ADLERTEG Jonna  Sweden  Artistic Gymnastics
# 124        AGGEFORS Mikael  Sweden             Handball
# 239       ALEXIUSSON Agnes  Sweden               Boxing
# ...                    ...     ...                  ...
# 10434         WANNE Hampus  Sweden             Handball
# 10443      WARHOLM Karsten  Norway            Athletics
# 10463         WATNDAL Erik  Norway             Shooting
# 10516     WESTBERG Johanna  Sweden             Handball
# 10559    WIKSTROM Carolina  Sweden            Athletics
#
# [266 rows x 3 columns]

# %% [markdown]
# 18. eliminare tutti gli atleti della Francia

# %%
atleti = atleti.drop(atleti.index[atleti['NOC'] == 'France'])
atleti
# Out:
#                         Name      NOC           Discipline
# 0            AALERUD Katrine   Norway         Cycling Road
# 1                ABAD Nestor    Spain  Artistic Gymnastics
# 2          ABAGNALE Giovanni    Italy               Rowing
# 3             ABALDE Alberto    Spain           Basketball
# 4              ABALDE Tamara    Spain           Basketball
# ...                      ...      ...                  ...
# 11080  ZWICKER Martin Detlef  Germany               Hockey
# 11081      ZWOLINSKA Klaudia   Poland         Canoe Slalom
# 11082           ZYKOVA Yulia      ROC             Shooting
# 11083      ZYUZINA Ekaterina      ROC              Sailing
# 11084        ZYZANSKA Sylwia   Poland              Archery
#
# [10708 rows x 3 columns]

# %% [markdown]
# #Verifica 3

# %% [markdown]
# Analizzare attentamente il file per capire bene come sono strutturati i dati e che cosa contengono. Creare poi un nuovo notebook chiamandolo con il proprio cognome in cui scrivere le istruzioni necessarie per:

# %% [markdown]
# 1. caricare i dati del file in un dataframe Pandas

# %%
teams = pd.read_excel('https://raw.githubusercontent.com/wtitze/3E/main/Teams.xlsx')

# %% [markdown]
# 2. visualizzare le discipline a cui l'Italia ha partecipato

# %%
disciplineItalia = list(set(teams[teams.NOC == 'Italy']['Discipline'].tolist()))
disciplineItalia
# Out:
# ['3x3 Basketball',
#  'Athletics',
#  'Basketball',
#  'Beach Volleyball',
#  'Baseball/Softball',
#  'Cycling Track',
#  'Rhythmic Gymnastics',
#  'Volleyball',
#  'Swimming',
#  'Artistic Gymnastics',
#  'Water Polo',
#  'Triathlon',
#  'Fencing',
#  'Archery',
#  'Artistic Swimming']

# %% [markdown]
# 3. visualizzare il numero di discipline a cui hanno partecipato gli Stati Uniti

# %%
disciplineUSA = list(set(teams[teams.NOC == 'United States of America']['Discipline']))
len(disciplineUSA)
# Out:
# 18

# %% [markdown]
# 4. visualizzare il numero di squadre di basket femminile

# %%
teams[(teams.Discipline == 'Basketball') & (teams.Event == 'Women')]['Event'].count()
# Out:
# 12

# %% [markdown]
# 5. visualizzare le discipline a cui hanno partecipato la Gran Bretagna e la Francia

# %%
disciplineGBFR = list(set(teams[(teams.NOC == 'Great Britain') | (teams.NOC == 'France')]['Discipline']))
disciplineGBFR
# Out:
# ['3x3 Basketball',
#  'Athletics',
#  'Basketball',
#  'Cycling Track',
#  'Volleyball',
#  'Rugby Sevens',
#  'Swimming',
#  'Artistic Gymnastics',
#  'Table Tennis',
#  'Handball',
#  'Football',
#  'Triathlon',
#  'Fencing',
#  'Archery',
#  'Hockey',
#  'Artistic Swimming']

# %% [markdown]
# 6. controllare se le discipline a cui ha partecipato l'Italia sono di più o di meno di quelle a cui ha partecipato la Spagna

# %%
if len(set(teams[teams.NOC == 'Italy']['Discipline'].tolist())) > len(set(teams[teams.NOC == 'Spain']['Discipline'].tolist())):
  print("L'Italia ha partecipato a più discipline rispetto alla Spagna")
else:
  print("La Spagna ha partecipato a più discipline rispetto all'Italia")
# Out:
# L'Italia ha partecipato a più discipline rispetto alla Spagna

# %% [markdown]
# 7. visualizzare tutti le discipline in cui compare la parola 'water'

# %%
list(set(teams[teams.Discipline.str.contains('Water')]['Discipline']))
# Out:
# ['Water Polo']

# %% [markdown]
# 8. visualizzare tutti i dati ordinandoli in ordine alfabetico sul nome della nazione

# %%
teams.sort_values('NOC')
# Out:
#                  Name           Discipline                       NOC  \
# 432            Angola             Handball                    Angola
# 494         Argentina         Rugby Sevens                 Argentina
# 404         Argentina             Football                 Argentina
# 241    Gallay/Pereyra     Beach Volleyball                 Argentina
# 240  Azaad/Capogrosso     Beach Volleyball                 Argentina
# ..                ...                  ...                       ...
# 742     United States           Water Polo  United States of America
# 493        Uzbekistan  Rhythmic Gymnastics                Uzbekistan
# 720         Venezuela           Volleyball                 Venezuela
# 68            Vietnam              Archery                   Vietnam
# 431            Zambia             Football                    Zambia
#
#                 Event
# 432             Women
# 494               Men
# 404               Men
# 241             Women
# ...

# %% [markdown]
# 9. eliminare tutti i record relativi alla Cina

# %%
teams = teams.drop(teams.index.values[(teams.NOC.str.contains('China'))|(teams.Name.str.contains('China'))])

# %% [markdown]
# Analizzare attentamente il file per capire bene come sono strutturati i dati e che cosa contengono. Scrivere poi le istruzioni necessarie per:

# %% [markdown]
# 1. caricare i dati del file in un dataframe Pandas

# %%
medals = pd.read_excel('https://raw.githubusercontent.com/wtitze/3E/main/Medals.xlsx')
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %% [markdown]
# 2. visualizzare il totale delle medaglie delle ultime 10 nazioni

# %%
medals.tail(10)['Total']
# Out:
# 83    4
# 84    2
# 85    1
# 86    1
# 87    1
# 88    1
# 89    1
# 90    1
# 91    1
# 92    1
# Name: Total, dtype: int64

# %% [markdown]
# 3. visualizzare la nazione (o le nazioni) che ha vinto, in totale, almeno 40 medaglie

# %%
medals[medals.Total > 40]
# Out:
#    Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0     1    United States of America    39      41      33    113
# 1     2  People's Republic of China    38      32      18     88
# 2     3                       Japan    27      14      17     58
# 3     4               Great Britain    22      21      22     65
# 4     5                         ROC    20      28      23     71
# 5     6                   Australia    17       7      22     46
#
#    Rank by Total
# 0              1
# 1              2
# 2              5
# 3              4
# 4              3
# 5              6

# %% [markdown]
# 4. visualizzare le nazioni che hanno vinto un numero totale di medaglie compreso tra 30 e 50

# %%
medals[(medals.Total > 30) & (medals.Total < 50)]
# Out:
#    Rank     Team/NOC  Gold  Silver  Bronze  Total  Rank by Total
# 5     6    Australia    17       7      22     46              6
# 6     7  Netherlands    10      12      14     36              9
# 7     8       France    10      12      11     33             10
# 8     9      Germany    10      11      16     37              8
# 9    10        Italy    10      10      20     40              7

# %% [markdown]
# 5. visualizzare il numero di nazioni che non hanno vinto medaglie d'oro ma hanno vinto almeno 3 medaglie d'argento

# %%
medals[(medals.Gold == 0)&(medals.Silver > 3)]
# Out:
#     Rank  Team/NOC  Gold  Silver  Bronze  Total  Rank by Total
# 65    66  Colombia     0       4       1      5             42

# %% [markdown]
# 6. visualizzare il numero totale complessivo di medaglie assegnate

# %%
medals['Total'].sum()
# Out:
# 1080

# %% [markdown]
# 7. visualizzare la nazione che ha vinto lo stesso numero di medaglie d'oro, d'argento e di bronzo

# %%
medals[(medals.Bronze == medals.Silver)  & (medals.Silver == medals.Gold)]
# Out:
# Empty DataFrame
# Columns: [Rank, Team/NOC, Gold, Silver, Bronze, Total, Rank by Total]
# Index: []

# %% [markdown]
# 8. visualizzare le nazioni che non hanno vinto medaglie d'argento

# %%
medals[medals.Silver == 0]
# Out:
#     Rank              Team/NOC  Gold  Silver  Bronze  Total  Rank by Total
# 31    32            Uzbekistan     3       0       2      5             42
# 38    39               Ireland     2       0       2      4             47
# 39    39                Israel     2       0       2      4             47
# 40    41                 Qatar     2       0       1      3             60
# 41    42               Bahamas     2       0       0      2             66
# 42    42                Kosovo     2       0       0      2             66
# 58    59               Estonia     1       0       1      2             66
# 59    59                  Fiji     1       0       1      2             66
# 60    59                Latvia     1       0       1      2             66
# 61    59              Thailand     1       0       1      2             66
# 62    63               Bermuda     1       0       0      1             77
# ...

# %% [markdown]
# 9. visualizzare le nazioni che hanno vinto un numero di medaglie d'argento superiore alla media

# %%
medals[medals.Silver > medals.Silver.mean()]
# Out:
#     Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0      1    United States of America    39      41      33    113
# 1      2  People's Republic of China    38      32      18     88
# 2      3                       Japan    27      14      17     58
# 3      4               Great Britain    22      21      22     65
# 4      5                         ROC    20      28      23     71
# 5      6                   Australia    17       7      22     46
# 6      7                 Netherlands    10      12      14     36
# 7      8                      France    10      12      11     33
# 8      9                     Germany    10      11      16     37
# 9     10                       Italy    10      10      20     40
# 10    11                      Canada     7       6      11     24
# 11    12                      Brazil     7       6       8     21
# 12    13                 New Zealand     7       6       7     20
# ...
